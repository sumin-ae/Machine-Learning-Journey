# %%
import pandas as pd 
import seaborn as sns

# %%
df=pd.read_csv('F:\Machine Learning 2026\Pandas\Datasets\Titanic.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_14748\950965785.py:1: SyntaxWarning: invalid escape sequence '\M'
#   df=pd.read_csv('F:\Machine Learning 2026\Pandas\Datasets\Titanic.csv')

# %%
df.shape
# Out:
# (891, 12)

# %%
df.sample(5, random_state=42)
# Out:
#      PassengerId  Survived  Pclass  \
# 709          710         1       3
# 439          440         0       2
# 840          841         0       3
# 720          721         1       2
# 39            40         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 709  Moubarek, Master. Halim Gonios ("William George")    male   NaN      1
# 439             Kvillner, Mr. Johan Henrik Johannesson    male  31.0      0
# 840                        Alhomaki, Mr. Ilmari Rudolf    male  20.0      0
# 720                  Harper, Miss. Annie Jessie "Nina"  female   6.0      0
# 39                         Nicola-Yarred, Miss. Jamila  female  14.0      1
#
#      Parch            Ticket     Fare Cabin Embarked
# 709      1              2661  15.2458   NaN        C
# 439      0        C.A. 18723  10.5000   NaN        S
# 840      0  SOTON/O2 3101287   7.9250   NaN        S
# 720      1            248727  33.0000   NaN        S
# 39       0              2651  11.2417   NaN        C

# %% [markdown]
# ### Categorical Data

# %% [markdown]
# a. CountPlot

# %%
sns.countplot(data=df, x='Survived',hue="Survived")

df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df['Survived'].value_counts().plot(kind='pie',autopct="%.2f%%")
# Out:
# <Axes: >

# %%
print(df['Fare'].mean())
# Out:
# 32.204207968574636

# %% [markdown]
# ## Working With Numerical Data

# %% [markdown]
# ### Histogram
